# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC

# %%
df = pd.read_csv('make_blobs_dataset.csv')
df
# Out:
#     Feature1  Feature2  Target
# 0   8.215974 -2.286723       0
# 1   5.429163 -9.280195       1
# 2   7.481698 -2.964036       0
# 3   7.933331 -3.515532       0
# 4   7.295732 -4.393924       0
# ..       ...       ...     ...
# 95  8.301286 -4.217227       0
# 96  5.761049 -9.599804       1
# 97  8.763617 -9.479390       1
# 98  5.871326 -9.539978       1
# 99  6.876983 -9.475530       1
#
# [100 rows x 3 columns]

# %%
x = df[['Feature1','Feature2']].values
y = df['Target'].values

# %%
clf = SVC(kernel='linear')
clf.fit(x,y)
# Out:
# SVC(kernel='linear')

# %%
# prediction
new_data =[[5.5,2.5]]
pred = clf.predict(new_data)
print('Prediction Result :',pred)
# Out:
# Prediction Result : [0]

# %%
# find accuracy
from sklearn.metrics import accuracy_score,classification_report
y_pred = clf.predict(x)
df['y_predict'] = y_pred
df
# Out:
#     Feature1  Feature2  Target  y_predict
# 0   8.215974 -2.286723       0          0
# 1   5.429163 -9.280195       1          1
# 2   7.481698 -2.964036       0          0
# 3   7.933331 -3.515532       0          0
# 4   7.295732 -4.393924       0          0
# ..       ...       ...     ...        ...
# 95  8.301286 -4.217227       0          0
# 96  5.761049 -9.599804       1          1
# 97  8.763617 -9.479390       1          1
# 98  5.871326 -9.539978       1          1
# 99  6.876983 -9.475530       1          1
#
# [100 rows x 4 columns]

# %%
accuracy = accuracy_score(y,y_pred)
accuracy
# Out:
# 1.0

# %%
# See support vectors
clf.support_vectors_
# Out:
# array([[ 7.27059007, -4.84225716],
#        [ 6.49868019, -7.13530714]])

# %%
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %%
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

X = df[['Feature1', 'Feature2']].values
y = df['Target'].values
plot_decision_regions(X=X, y=y, clf=clf)

plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.title('SVM Decision Boundary')
plt.show()
